# %% [markdown]
# # DTSC-580: Data Manipulation
# ## Assignment: Survivor
#
# ### Name:
#
# ## Overview
#
# In this assignment, you will test all the skills that you have learned during this course to manipulate the provided data to find the answers to questions about the TV show Survivor.  If you are not familiar with this show, start by watching this short clip that briefly explains it:  [Survivor Explained](https://www.youtube.com/watch?v=l1-hTpG_krk)
#
# Please note that your notebook should be named `survivor` when submitting to CodeGrade for the automatic grading to work properly.
#
# ## Data
#
# The Survivor data is a R package from Daniel Oehm.  Daniel has made the data for this package available as an Excel file as explained in his article on [gradientdescending.com](http://gradientdescending.com/survivor-data-from-the-tv-series-in-r/).  Please make sure that you use the file from our Brightspace page though to make sure that your data will match what CodeGrade is expecting.  We have also updated some errors in the file, which is another reason that you must use the data given to you.
#
# You need to first read the article on the website linked above.  This will give you additional details about the data that will be important as you answer the questions below.
#
# Please note that there is a data dictionary in the file that explains the columns in the data.  You will also want to become familiar with the various spreadsheets and column names.  This will help you out tremendously in this assignment.
#
# Finally, here are a couple of things to know for those of you that have not seen the show:
# - Survivor is a reality TV show that first aired May 31, 2000 and is currently still on TV.
# - Contestants are broken up into two teams (usually) where they live in separate camps.
# - The teams compete in various challenges for rewards (food, supplies, brief experience trips, etc) and tribal immunity.
# - The team that loses a challenge, and therefore doesn't get the tribal immunity, goes to tribal council where they have to vote one of their members out (this data is represented in the "Vote History" spreadsheet).
# - After there are a small number of contestants left, the tribes are merged into one tribe where each contestant competes for individual immunity.  The winner of the individual immunity cannot get voted out and is safe at the next tribal council.
# - The are also hidden immunity idols that are hidden around the campground.  If a contestant finds and plays their hidden immunity at the tribal council, then all votes against them do not count, and the player with the next highest number of votes goes home.
# - When the contestants get down to 2 or 3 people, a number of the last contestants, known as the jury, come back to vote for the person who they think should win the game.  The winner is the one who gets the most jury votes (this data is represented in the "Jury Votes" spreadsheet).  This person is known as the Sole Survivor.
# - Voting recap:
#     - Tribal Council votes (Vote History spreadsheet) are bad; contestants with the most votes get sent home
#     - Jury Votes (Jury Votes spreadsheet) are good; contestants with the most votes win the game and is the Sole Survivor
#
# ## Note
#
# <u>Show Work</u>
#
# Remember that you must show your work.  Students submissions are spot checked manually to verify that they are not hard coding the answer from looking only in the file or in CodeGrade's expected output.  If this is seen, the student's answer will be manually marked wrong and their grade will be changed to reflect this.
#
# For example, if the question is who is the contestant who has received the most tribal votes to be voted out.  Select their record from the `castaway_details` DataFrame.
#
# You would show your work and code similar to this:
# ```
# ### incorrect way ###
# Q1 = castaway_details[castaway_details['castaway_id'] ==  333]
#
# ### correct way - showing your work ###
# # get index
# idx = vote_history.groupby('vote_id').size().sort_values(ascending=False).index[0]
#
# # select row based on index
# Q1 = castaway_details[castaway_details['castaway_id'] ==  idx]
# ```
#
# <u>Use Copy</u>
#
# Don't change any of the original DataFrames unless specifically asked or CodeGrade will not work correctly for this assignment.  Make sure you use `copy()` if needed.

# %%
# standard imports
import pandas as pd
import numpy as np

# Do not change this option; This allows the CodeGrade auto grading to function correctly
pd.set_option('display.max_columns', None)

# %% [markdown]
# First, import the data from the `survivor.xlsx` file, calling the respective DataFrames the same as the sheet name but with lowercase and [snake case](https://en.wikipedia.org/wiki/Snake_case).  For example, the sheet called `Castaway Details` should be saved as a DataFrame called `castaway_details`.  Make sure that the data files are in the same folder as your notebook.
#
# Note:  You may or may not need to install [openpyxl](https://openpyxl.readthedocs.io/en/stable/) for the code below to work.  You can use: `$ pip install openpyxl`

# %%
# import data from Excel

# setup Filename and Object
fileName = "survivor.xlsx"
xls = pd.ExcelFile(fileName)

# import individual sheets
castaway_details = pd.read_excel(xls, 'Castaway Details')
castaways = pd.read_excel(xls, 'Castaways')
challenge_description = pd.read_excel(xls, 'Challenge Description')
challenge_results = pd.read_excel(xls, 'Challenge Results')
confessionals = pd.read_excel(xls, 'Confessionals')
hidden_idols = pd.read_excel(xls, 'Hidden Idols')
jury_votes = pd.read_excel(xls, 'Jury Votes')
tribe_mapping = pd.read_excel(xls, 'Tribe Mapping')
viewers = pd.read_excel(xls, 'Viewers')
vote_history = pd.read_excel(xls, 'Vote History')
season_summary = pd.read_excel(xls, 'Season Summary')
season_palettes = pd.read_excel(xls, 'Season Palettes')
tribe_colours = pd.read_excel(xls, 'Tribe Colours')

# %% [markdown]
# **Exercise1:** Change every column name of every DataFrame to lowercase and snake case.  This is a standard first step for some programmers as lowercase makes it easier to write and snake case makes it easier to copy multiple-word column names.
#
# For example, `Castaway Id` should end up being `castaway_id`.  You should try doing this using a `for` loop instead of manually changing the names for each column.  It should take you no more than a few lines of code.  Use stackoverflow if you need help.

# %%
sheet_list = [castaway_details,
          castaways,challenge_description,
          challenge_results,confessionals,
          hidden_idols,jury_votes,
          tribe_mapping,viewers,
          vote_history,
          season_summary,
          season_palettes,
          tribe_colours]

def column_name(i):
    i.columns = [x.replace(" ","_").lower() for x in i]  

for item in sheet_list:
    column_name(item)

# %% [markdown]
# **Q2:** What contestant was the oldest at the time of their season?  We want to look at their age at the time of the season and NOT their current age.  Select their row from the `castaway_details` DataFrame and save this as `Q2`.  This should return a DataFrame and the index and missing values should be left as is.

# %%
castaway_details_merge = castaway_details.merge(castaways, left_on = "full_name", right_on = "full_name")
castaway_details_merge_2 = castaway_details_merge.merge(season_summary, left_on = "season", right_on = "season")
idx = castaway_details_merge_2.sort_values(by = ["age"], ascending = False).index[1]
Q2 = castaway_details.loc[[idx]]

# %% [markdown]
# **Q3:** What contestant played in the most number of seasons? Select their row from the `castaway_details` DataFrame and save this as `Q3`.  This should return a DataFrame and the index and missing values should be left as is.

# %%
castaway_details_merge_2_drop_dup = castaway_details_merge_2.drop_duplicates(
  subset = ['full_name_x', 'season'],
  keep = 'last')

castaway_details_merge_2_drop_dup
# Out:
#      castaway_id_x        full_name_x short_name date_of_birth date_of_death  \
# 0                1  Sonja Christopher      Sonja    1937-01-28           NaT
# 1                2      B.B. Andersen       B.B.    1936-01-18    2013-10-29
# 2                3    Stacey Stillman     Stacey    1972-08-11           NaT
# 3                4        Ramona Gray     Ramona    1971-01-20           NaT
# 4                5          Dirk Been       Dirk    1976-06-15           NaT
# ..             ...                ...        ...           ...           ...
# 752            604      Tiffany Seely    Tiffany    1973-12-08           NaT
# 753            605       Sydney Segal     Sydney    1995-07-19           NaT
# 754            606      Shantel Smith       Shan    1987-03-11           NaT
# 755            607         David Voce       Voce    1986-05-01           NaT
# 756            608      Liana Wallace      Liana    2000-10-25           NaT
#
#      gender   race ethnicity             occupation personality_type_x  \
# 0    Female    NaN       NaN               Musician               ENFP
# 1      Male    NaN       NaN  Real Estate Developer               ESTJ
# 2    Female    NaN       NaN               Attorney               ENTJ
# 3    Female  Black       NaN     Biochemist/Chemist               ISTJ
# 4      Male    NaN       NaN           Dairy Farmer               ISFP
# ..      ...    ...       ...                    ...                ...
# 752  Female  White    Jewish                Teacher               ENTP
# 753  Female  White    Jewish            Law Student               ESTP
# 754  Female  Black       NaN                 Pastor               ENFJ
# 755    Male    NaN       NaN           Neurosurgeon               ENTJ
# 756  Female  Black    Jewish        College Student               ESTJ
#
#         season_name_x  season  castaway_id_y castaway  age           city  \
# 0    Survivor: Borneo       1              1    Sonja   63   Walnut Creek
# 1    Survivor: Borneo       1              2     B.B.   64  Mission Hills
# 2    Survivor: Borneo       1              3   Stacey   27  San Francisco
# 3    Survivor: Borneo       1              4   Ramona   29         Edison
# 4    Survivor: Borneo       1              5     Dirk   23   Spring Green
# ..                ...     ...            ...      ...  ...            ...
# 752      Survivor: 41      41            604  Tiffany   47      Plainview
# 753      Survivor: 41      41            605   Sydney   26       Brooklyn
# 754      Survivor: 41      41            606     Shan   34     Washington
# 755      Survivor: 41      41            607     Voce   35        Chicago
# 756      Survivor: 41      41            608    Liana   20     Washington
#
#           state personality_type_y  episode  day  order          result  \
# 0    California               ENFP        1    3      1   1st voted out
# 1        Kansas               ESTJ        2    6      2   2nd voted out
# 2    California               ENTJ        3    9      3   3rd voted out
# 3    New Jersey               ISTJ        4   12      4   4th voted out
# 4     Wisconsin               ISFP        5   15      5   5th voted out
# ..          ...                ...      ...  ...    ...             ...
# 752    New York               ENTP        8   16      8   8th voted out
# 753    New York               ESTP        7   14      7   7th voted out
# 754        D.C.               ENFJ       10   19     11  11th voted out
# 755    Illinois               ENTJ        2    5      3   3rd voted out
# 756        D.C.               ESTJ       11   21     12  12th voted out
#
#          jury_status original_tribe swapped_tribe swapped_tribe_2  \
# 0                NaN           Tagi           NaN             NaN
# 1                NaN         Pagong           NaN             NaN
# 2                NaN           Tagi           NaN             NaN
# 3                NaN         Pagong           NaN             NaN
# 4                NaN           Tagi           NaN             NaN
# ..               ...            ...           ...             ...
# 752  1st jury member           Yase           NaN             NaN
# 753              NaN           Luvu           NaN             NaN
# 754  4th jury member             Ua           NaN             NaN
# 755              NaN           Yase           NaN             NaN
# 756  5th jury member           Yase           NaN             NaN
#
#     merged_tribe  total_votes_received  immunity_idols_won     season_name_y  \
# 0            NaN                     4                   0  Survivor: Borneo
# 1            NaN                     6                   1  Survivor: Borneo
# 2            NaN                     6                   1  Survivor: Borneo
# 3            NaN                     6                   2  Survivor: Borneo
# 4            NaN                     4                   2  Survivor: Borneo
# ..           ...                   ...                 ...               ...
# 752     Via Kana                     8                   4      Survivor: 41
# 754           NaT             6.25            5.82              4.0
# 755           NaT             6.25            5.82              4.0
# 756           NaT             6.25            5.82              4.0
#
#      viewers_mean  rank
# 0            28.3   2.0
# 1            28.3   2.0
# 2            28.3   2.0
# 3            28.3   2.0
# 4            28.3   2.0
# ..            ...   ...
# 752           NaN   NaN
# 753           NaN   NaN
# 754           NaN   NaN
# 755           NaN   NaN
# 756           NaN   NaN
#
# [744 rows x 48 columns]

# %%
castaway_details_merge_2_drop_dup_grouped = castaway_details_merge_2_drop_dup.groupby("full_name_x")
castaway_details_merge_2_drop_dup_grouped = castaway_details_merge_2_drop_dup_grouped.count().sort_values(by = ["season"], ascending = False)
castaway_details_merge_2_drop_dup_grouped.head(10)
# Out:
#                    castaway_id_x  short_name  date_of_birth  date_of_death  \
# full_name_x
# Rob Mariano                    5           5              5              0
# Cirie Fields                   4           4              4              0
# Rupert Boneham                 4           4              4              0
# Oscar Lusth                    4           4              4              0
# Parvati Shallow                4           4              4              0
# Sandra Diaz-Twine              4           4              4              0
# Tyson Apostol                  4           4              4              0
# Jerri Manthey                  3           3              3              0
# James Thomas Jr.               3           3              3              0
# Andrea Boehlke                 3           3              3              0
#
#                    gender  race  ethnicity  occupation  personality_type_x  \
# full_name_x
# Rob Mariano             5     0          0           5                   5
# Cirie Fields            4     4          0           4                   4
# Rupert Boneham          4     0          0           4                   4
# Oscar Lusth             4     4          4           4                   4
# Parvati Shallow         4     4          0           4                   4
# Sandra Diaz-Twine       4     0          4           4                   4
# Tyson Apostol           4     0          0           4                   4
# Jerri Manthey           3     0          0           3                   3
# James Thomas Jr.        3     0          0           3                   3
# Andrea Boehlke          3     0          0           3                   3
#
#                    season_name_x  season  castaway_id_y  castaway  age  city  \
# full_name_x
# Rob Mariano                    5       5              5         5    5     5
# Cirie Fields                   4       4              4         4    4     4
# Rupert Boneham                 4       4              4         4    4     4
# Oscar Lusth                    4       4              4         4    4     4
# Parvati Shallow                4       4              4         4    4     4
# Sandra Diaz-Twine              4       4              4         4    4     4
# Tyson Apostol                  4       4              4         4    4     4
# Jerri Manthey                  3       3              3         3    3     3
# James Thomas Jr.               3       3              3         3    3     3
# Andrea Boehlke                 3       3              3         3    3     3
#
#                    state  personality_type_y  episode  day  order  result  \
# full_name_x
# Rob Mariano            5                   5        5    5      5       5
# Cirie Fields           4                   4        4    4      4       4
# Rupert Boneham         4                   4        4    4      4       4
# Oscar Lusth            4                   4        4    4      4       4
# Parvati Shallow        4                   4        4    4      4       4
# Sandra Diaz-Twine      4                   4        4    4      4       4
# Tyson Apostol          4                   4        4    4      4       4
# Jerri Manthey          3                   3        3    3      3       3
# James Thomas Jr.       3                   3        3    3      3       3
# Andrea Boehlke         3                   3        3    3      3       3
#
#                    jury_status  original_tribe  swapped_tribe  \
# full_name_x
# Rob Mariano                  1               5              3
# Cirie Fields                 3               4              3
# Rupert Boneham               3               4              2
# Oscar Lusth                  2               4              3
# Parvati Shallow              2               4              3
# Sandra Diaz-Twine            0               4              3
# Tyson Apostol                1               4              1
# Jerri Manthey                2               3              1
# James Thomas Jr.             1               3              1
# Andrea Boehlke               2               3              2
#
#                    swapped_tribe_2  merged_tribe  total_votes_received  \
# full_name_x
# Rob Mariano                      1             3                     5
# Cirie Fields                     0             3                     4
# Rupert Boneham                   1             3                     4
# Oscar Lusth                      1             3                     4
# Parvati Shallow                  1             3                     4
# Sandra Diaz-Twine                0             2                     4
# Tyson Apostol                    0             2                     4
# Jerri Manthey                    1             2                     3
# James Thomas Jr.                 0             2                     3
# Andrea Boehlke                   0             3                     3
#
#                    immunity_idols_won  season_name_y  location  country  \
# full_name_x
# Rob Mariano                         5              5         5        5
# Cirie Fields                        4              4         4        4
# Rupert Boneham                      4              4         4        4
# Oscar Lusth                         4              4         4        4
# Parvati Shallow                     4              4         4        4
# Sandra Diaz-Twine                   4              4         4        4
# Tyson Apostol                       4              4         4        4
# Jerri Manthey                       3              3         3        3
# James Thomas Jr.                    3              3         3        3
# Andrea Boehlke                      3              3         3        3
#
#                    tribe_setup  full_name_y  winner_id  winner  runner_ups  \
# full_name_x
# Rob Mariano                  5            5          5       5           5
# Cirie Fields                 4            4          4       4           4
# Rupert Boneham               4            4          4       4           4
# Oscar Lusth                  4            4          4       4           4
# Parvati Shallow              4            4          4       4           4
# Sandra Diaz-Twine            4            4          4       4           4
# Tyson Apostol                4            4          4       4           4
# Jerri Manthey                3            3          3       3           3
# James Thomas Jr.             3            3          3       3           3
# Andrea Boehlke               3            3          3       3           3
#
#                    final_vote  timeslot  premiered  ended  filming_started  \
# full_name_x
# Rob Mariano                 5         5          5      5                5
# Cirie Fields                4         4          4      4                4
# Rupert Boneham              4         4          4      4                4
# Oscar Lusth                 4         4          4      4                4
# Parvati Shallow             4         4          4      4                4
# Sandra Diaz-Twine           4         4          4      4                4
# Tyson Apostol               4         4          4      4                4
# Jerri Manthey               3         3          3      3                3
# James Thomas Jr.            3         3          3      3                3
# Andrea Boehlke              3         3          3      3                3
#
#                    filming_ended  viewers_premier  viewers_finale  \
# full_name_x
# Rob Mariano                    5                5               5
# Cirie Fields                   4                4               4
# Rupert Boneham                 4                4               4
# Oscar Lusth                    4                4               4
# Parvati Shallow                4                4               4
# Sandra Diaz-Twine              4                4               4
# Tyson Apostol                  4                4               4
# Jerri Manthey                  3                3               3
# James Thomas Jr.               3                3               3
# Andrea Boehlke                 3                3               3
#
#                    viewers_reunion  viewers_mean  rank
# full_name_x
# Rob Mariano                      5             4     4
# Cirie Fields                     4             4     4
# Rupert Boneham                   4             4     4
# Oscar Lusth                      4             4     4
# Parvati Shallow                  4             3     3
# Sandra Diaz-Twine                4             3     3
# Tyson Apostol                    4             3     3
# Jerri Manthey                    3             3     3
# James Thomas Jr.                 3             3     3
# Andrea Boehlke                   3             3     3

# %%
Q3 = castaway_details.iloc[[54]]
Q3
# Out:
#     castaway_id    full_name  short_name date_of_birth date_of_death gender  \
# 54           55  Rob Mariano  Boston Rob    1975-12-25           NaT   Male
#
#    race ethnicity           occupation personality_type
# 54  NaN       NaN  Construction Worker             ESTJ

# %% [markdown]
# **Q4:** Create a DataFrame of all the contestants that won their season (aka their final result in the `castaways` DataFrame was the 'Sole Survivor').  Call this DataFrame `sole_survivor`.  Note that contestants may appear more than one time in this DataFrame if they won more than one season.  Make sure that the index goes from 0 to n-1 and that the DataFrame is sorted ascending by season number.
#
# The DataFrame should have the same columns, and the columns should be in the same order, as the `castaways` DataFrame.

# %%
sole_survivor = castaways[castaways["result"] == "Sole Survivor"].reset_index(drop = True).sort_values(by = ["season"]).reset_index(drop = True)
sole_survivor
# Out:
#                                   season_name  season           full_name  \
# 0                            Survivor: Borneo       1       Richard Hatch
# 1            Survivor: The Australian Outback       2         Tina Wesson
# 2                            Survivor: Africa       3          Ethan Zohn
# 3                         Survivor: Marquesas       4      Vecepia Towery
# 4                          Survivor: Thailand       5        Brian Heidik
# 5                        Survivor: The Amazon       6       Jenna Morasca
# 6                     Survivor: Pearl Islands       7   Sandra Diaz-Twine
# 7                         Survivor: All-Stars       8        Amber Brkich
# 8                           Survivor: Vanuatu       9     Chris Daugherty
# 9                             Survivor: Palau      10         Tom Westman
# 10                        Survivor: Guatemala      11    Danni Boatwright
# 11                           Survivor: Panama      12     Aras Baskauskas
# 12                     Survivor: Cook Islands      13            Yul Kwon
# 13                             Survivor: Fiji      14           Earl Cole
# 14                            Survivor: China      15         Todd Herzog
# 15                       Survivor: Micronesia      16     Parvati Shallow
# 16                            Survivor: Gabon      17      Robert Crowley
# 17                        Survivor: Tocantins      18    James Thomas Jr.
# 18                            Survivor: Samoa      19       Natalie White
# 19              Survivor: Heroes vs. Villains      20   Sandra Diaz-Twine
# 20                        Survivor: Nicaragua      21           Jud Birza
# 21                Survivor: Redemption Island      22         Rob Mariano
# 22                    Survivor: South Pacific      23       Sophie Clarke
# 23                        Survivor: One World      24        Kim Spradlin
# 24                      Survivor: Philippines      25      Denise Stapley
# 25                         Survivor: Caramoan      26        John Cochran
# 26                  Survivor: Blood vs. Water      27       Tyson Apostol
# 27                          Survivor: Cagayan      28        Tony Vlachos
# 28                 Survivor: San Juan del Sur      29    Natalie Anderson
# 29                     Survivor: Worlds Apart      30       Mike Holloway
# 30                         Survivor: Cambodia      31      Jeremy Collins
# 31                        Survivor: Kaoh Rong      32  Michele Fitzgerald
# 32            Survivor: Millennials vs. Gen X      33          Adam Klein
# 33                    Survivor: Game Changers      34        Sarah Lacina
# 34  Survivor: Heroes vs. Healers vs. Hustlers      35      Ben Driebergen
# 35                     Survivor: Ghost Island      36     Wendell Holland
# 36                Survivor: David vs. Goliath      37         Nick Wilson
# 37               Survivor: Edge of Extinction      38     Chris Underwood
# 38              Survivor: Island of the Idols      39       Tommy Sheehan
# 39                   Survivor: Winners at War      40        Tony Vlachos
# 40                               Survivor: 41      41     Erika Casupanan
#
#     castaway_id    castaway  age                  city           state  \
# 0            16     Richard   39               Newport    Rhode Island
# 1            32        Tina   40             Knoxville       Tennessee
# 2            48       Ethan   27             Lexington   Massachusetts
# 3            64     Vecepia   36               Hayward      California
# 4            80       Brian   34           Quartz Hill      California
# 5            96       Jenna   21           Bridgeville    Pennsylvania
# 6           112      Sandra   29            Fort Lewis      Washington
# 7            27       Amber   25                Beaver    Pennsylvania
# 8           130       Chris   33          South Vienna            Ohio
# 9           150         Tom   40              Sayville        New York
# 10          166       Danni   29            Tonganoxie          Kansas
# 11          182        Aras   24          Santa Monica      California
# 12          202         Yul   31             San Mateo      California
# 13          221        Earl   35          Santa Monica      California
# 14          237        Todd   22        Pleasant Grove            Utah
# 15          197     Parvati   25           Los Angeles      California
# 16          265         Bob   57        South Portland           Maine
# 17          281        J.T.   24                Mobile         Alabama
# 18          301     Natalie   26             Van Buren        Arkansas
# 19          112      Sandra   35          Fayetteville  North Carolina
# 20          321       Fabio   21                Venice      California
# 21           55  Boston Rob   34             Pensacola         Florida
# 22          353      Sophie   22             Willsboro        New York
# 23          371         Kim   29           San Antonio           Texas
# 24          386      Denise   41          Cedar Rapids            Iowa
# 25          348     Cochran   25            Washington            D.C.
# 26          274       Tyson   34                 Provo            Utah
# 27          424        Tony   39           Jersey City      New Jersey
# 28          442     Natalie   28             Edgewater      New Jersey
# 29          460        Mike   38  North Richland Hills           Texas
# 30          433      Jeremy   37               Foxboro   Massachusetts
# 31          478     Michele   24              Freehold      New Jersey
# 32          498        Adam   25         San Francisco      California
# 33          414       Sarah   32                Marion            Iowa
# 34          516         Ben   34                 Boise           Idaho
# 35          536     Wendell   33          Philadelphia    Pennsylvania
# 36          556        Nick   27          Williamsburg        Kentucky
# 37          559       Chris   25            Greenville  South Carolina
# 38          590       Tommy   26            Long Beach        New York
# 39          424        Tony   45             Allendale      New Jersey
# 40          594       Erika   32               Toronta         Ontario
#
#    personality_type  episode  day  order         result jury_status  \
# 0              ENTP       14   39     16  Sole Survivor         NaN
# 1              ESFJ       16   42     16  Sole Survivor         NaN
# 2              ISFP       15   39     16  Sole Survivor         NaN
# 3              ISTJ       15   39     16  Sole Survivor         NaN
# 4              ISTP       15   39     16  Sole Survivor         NaN
# 5              ISTP       15   39     16  Sole Survivor         NaN
# 6              ESTP       15   39     18  Sole Survivor         NaN
# 7              ISFP       17   39     18  Sole Survivor         NaN
# 8              ENTP       15   39     18  Sole Survivor         NaN
# 9              ESTJ       15   39     20  Sole Survivor         NaN
# 10             ENFJ       15   39     18  Sole Survivor         NaN
# 11             INFP       16   39     16  Sole Survivor         NaN
# 12             INTJ       16   39     20  Sole Survivor         NaN
# 13             INFJ       15   39     19  Sole Survivor         NaN
# 14             ENFP       15   39     16  Sole Survivor         NaN
# 15             ENFJ       15   39     20  Sole Survivor         NaN
# 16             INTP       14   39     18  Sole Survivor         NaN
# 17             ESTP       15   39     16  Sole Survivor         NaN
# 18             ISFJ       16   39     20  Sole Survivor         NaN
# 19             ESTP       15   39     20  Sole Survivor         NaN
# 20             ESFP       16   39     20  Sole Survivor         NaN
# 21             ESTJ       15   39     20  Sole Survivor         NaN
# 22             INTJ       16   39     20  Sole Survivor         NaN
# 23             INFJ       15   39     18  Sole Survivor         NaN
# 24             INFJ       15   39     18  Sole Survivor         NaN
# 25             INTP       15   39     20  Sole Survivor         NaN
# 26             ESTP       15   39     23  Sole Survivor         NaN
# 27             ESTP       14   39     18  Sole Survivor         NaN
# 28             ESTP       15   39     18  Sole Survivor         NaN
# 29             ESTP       15   39     18  Sole Survivor         NaN
# 30             ESTJ       15   39     20  Sole Survivor         NaN
# 31             ESFP       15   39     18  Sole Survivor         NaN
# 32             ENTP       14   39     20  Sole Survivor         NaN
# 33             ENTJ       14   39     20  Sole Survivor         NaN
# 34             ESFP       14   39     18  Sole Survivor         NaN
# 35             INFJ       14   39     20  Sole Survivor         NaN
# 36             ENTP       14   39     20  Sole Survivor         NaN
# 37             ENTP       14   39     20  Sole Survivor         NaN
# 38             ENFJ       14   39     20  Sole Survivor         NaN
# 39             ESTP       15   39     22  Sole Survivor         NaN
# 40             ENFP       13   26     18  Sole Survivor         NaN
#
#    original_tribe swapped_tribe swapped_tribe_2  merged_tribe  \
# 0            Tagi           NaN             NaN       Rattana
# 1          Ogakor           NaN             NaN    Barramundi
# 2           Boran         Boran             NaN     Moto Maji
# 3         Maraamu          Rotu             NaN      Soliantu
# 4      Chuay Gahn           NaN             NaN     Chuay Jai
# 5          Jaburu        Jaburu             NaN        Jacaré
# 6           Drake         Drake             NaN        Balboa
# 7         Chapera       Chapera         Chapera  Chaboga Mogo
# 8          Lopevi        Lopevi             NaN        Alinta
# 9           Koror           NaN             NaN         Koror
# 10          Nakúm         Yaxhá             NaN        Xhakúm
# 11        Viveros        Casaya             NaN       Gitanos
# 12      Puka Puka      Aitutaki        Aitutaki     Aitutonga
# 13           Ravu          Moto             NaN     Bula Bula
# 14       Fei Long      Fei Long             NaN   Hae Da Fung
# 15        Malakal         Airai             NaN          Dabu
# 16           Kota          Kota            Kota         Nobag
# 17        Jalapao           NaN             NaN         Forza
# 18        Foa Foa           NaN             NaN          Aiga
# 19       Villains           NaN             NaN      Yin Yang
# 20        La Flor       La Flor             NaN      Libertad
# 21        Ometepe           NaN             NaN      Murlonio
# 22          Upolu           NaN             NaN       Te Tuna
# 23         Salani        Salani             NaN       Tikiano
# 24        Matsing       Kalabaw             NaN     Dangrayne
# 25          Bikal         Bikal             NaN     Enil Edam
# 26         Galang       Tadhana             NaN        Kasama
# 27         Aparri        Solana             NaN     Solarrion
# 28        Hunahpu       Hunahpu             NaN        Huyopa
# 29       Escameca      Escameca             NaN        Merica
# 30          Bayon         Bayon           Bayon         Orkun
# 31         Gondol      Chan Loh             NaN          Dara
# 32          Vanua        Takali             NaN        Vinaka
# 33           Nuku         Tavua             NaN     Maku Maku
# 34           Levu          Yawa             NaN        Solewa
# 35         Naviti        Naviti          Yanuya        Lavita
# 36          David        Jabeni             NaN      Kalokalo
# 37           Manu           NaN             NaN          Vata
# 38          Vokai         Vokai             NaN      Lumuwaku
# 39          Dakal         Dakal             NaN          Koru
# 40           Luvu           NaN             NaN      Via Kana
#
#     total_votes_received  immunity_idols_won
# 0                      6                   4
# 1                      0                   2
# 2                      0                   4
# 3                      2                   4
# 4                      0                   8
# 5                      3                   7
# 6                      0                   3
# 7                      6                   6
# 8                      3                   6
# 9                      0                  12
# 10                     1                   5
# 11                     9                   4
# 12                     5                   6
# 13                     1                   5
# 14                     5                   4
# 15                     4                   7
# 16                     2                   8
# 17                     0                   5
# 18                     8                   1
# 19                     3                   4
# 20                     2                   8
# 21                     7                   9
# 22                     5                   6
# 23                     3                   6
# 24                     6                   1
# 25                     0                   7
# 26                     2                   8
# 27                     5                   6
# 28                     0                   6
# 29                     4                   7
# 30                     3                   7
# 31                     1                   7
# 32                     6                   6
# 33                     0                   4
# 34                    11                   4
# 35                     5                   8
# 36                     0                   4
# 37                     9                   1
# 38                     2                   6
# 39                     0                   9
# 40                     2                   8

# %% [markdown]
# **Q5:** Have any contestants won more than one time?  If so, select their records from the `sole_survivor` DataFrame, sorting the rows by season.  Save this as `Q5`.  If no contestant has won twice, save `Q5` as the string `None`.

# %%
sole_survivor_grouped = sole_survivor.groupby("full_name")
sole_survivor_grouped.count()[["season"]]
# Out:
#                     season
# full_name
# Adam Klein               1
# Amber Brkich             1
# Aras Baskauskas          1
# Ben Driebergen           1
# Brian Heidik             1
# Chris Daugherty          1
# Chris Underwood          1
# Danni Boatwright         1
# Denise Stapley           1
# Earl Cole                1
# Erika Casupanan          1
# Ethan Zohn               1
# James Thomas Jr.         1
# Jenna Morasca            1
# Jeremy Collins           1
# John Cochran             1
# Jud Birza                1
# Kim Spradlin             1
# Michele Fitzgerald       1
# Mike Holloway            1
# Natalie Anderson         1
# Natalie White            1
# Nick Wilson              1
# Parvati Shallow          1
# Richard Hatch            1
# Rob Mariano              1
# Robert Crowley           1
# Sandra Diaz-Twine        2
# Sarah Lacina             1
# Sophie Clarke            1
# Tina Wesson              1
# Todd Herzog              1
# Tom Westman              1
# Tommy Sheehan            1
# Tony Vlachos             2
# Tyson Apostol            1
# Vecepia Towery           1
# Wendell Holland          1
# Yul Kwon                 1

# %%
Q5 = sole_survivor[(sole_survivor["full_name"] == "Sandra Diaz-Twine") | (sole_survivor["full_name"] == "Tony Vlachos")]
Q5
# Out:
#                       season_name  season          full_name  castaway_id  \
# 6         Survivor: Pearl Islands       7  Sandra Diaz-Twine          112
# 19  Survivor: Heroes vs. Villains      20  Sandra Diaz-Twine          112
# 27              Survivor: Cagayan      28       Tony Vlachos          424
# 39       Survivor: Winners at War      40       Tony Vlachos          424
#
#    castaway  age          city           state personality_type  episode  day  \
# 6    Sandra   29    Fort Lewis      Washington             ESTP       15   39
# 19   Sandra   35  Fayetteville  North Carolina             ESTP       15   39
# 27     Tony   39   Jersey City      New Jersey             ESTP       14   39
# 39     Tony   45     Allendale      New Jersey             ESTP       15   39
#
#     order         result jury_status original_tribe swapped_tribe  \
# 6      18  Sole Survivor         NaN          Drake         Drake
# 19     20  Sole Survivor         NaN       Villains           NaN
# 27     18  Sole Survivor         NaN         Aparri        Solana
# 39     22  Sole Survivor         NaN          Dakal         Dakal
#
#    swapped_tribe_2 merged_tribe  total_votes_received  immunity_idols_won
# 6              NaN       Balboa                     0                   3
# 19             NaN     Yin Yang                     3                   4
# 27             NaN    Solarrion                     5                   6
# 39             NaN         Koru                     0                   9

# %% [markdown]
# **Q6:** What is the average age of contestants when they appeared on the show?  Save this as `Q6`.  Round to nearest integer.

# %%
Q6 = int(castaways["age"].mean())
Q6
# Out:
# 33

# %% [markdown]
# **Q7:** Who played the most total number of days of Survivor? If a contestant appeared on more than one season, you would add their total days for each season together. Save the top five contestants in terms of total days played as a DataFrame and call it `Q7`, sorted in descending order by total days played.
#
# The following columns should be included: `castaway_id`, `full_name`, and `total_days_played` where `total_days_played` is the sum of all days a contestant played. The index should go from 0 to n-1.
#
# Note:  Be careful because on some seasons, the contestant was allowed to come back into the game after being voted off.  Take a look at [Season 23's contestant Oscar Lusth](https://en.wikipedia.org/wiki/Ozzy_Lusth#South_Pacific) in the `castaways` DataFrame as an example.  He was voted out 7th and then returned to the game.  He was then voted out 9th and returned to the game a second time.  He was then voted out 17th the final time.  Be aware of this in your calculations and make sure you are counting the days according to the last time they were voted off or won.

# %%
names_list = castaways['full_name'].tolist()
days_list = []

def days(x):
    
    castaways_2 = castaways[castaways["full_name"] == str(x)]
    castaways_2 = castaways_2.drop_duplicates(["season","full_name"])
    castaways_2 = castaways_2["day"].sum()
    days_list.append(castaways_2)
    

for item in names_list:
    days(item)

# %%
days_dataframe = pd.DataFrame({"full_name" : names_list, "total_days_played" : days_list}).drop_duplicates(["full_name","total_days_played"]).sort_values(by = ["total_days_played"], ascending = False).head(5)
days_dataframe
# Out:
#              full_name  total_days_played
# 34         Rob Mariano                131
# 33     Parvati Shallow                130
# 149        Oscar Lusth                128
# 143       Cirie Fields                121
# 32   Sandra Diaz-Twine                110

# %%
names_list_2 = days_dataframe.loc[:,"full_name"]
names_list_2

castaways_df = castaways[castaways.full_name.isin(names_list_2)].drop_duplicates(subset = ["full_name"])
castaways_df
# Out:
#                   season_name  season          full_name  castaway_id  \
# 32   Survivor: Winners at War      40  Sandra Diaz-Twine          112
# 33   Survivor: Winners at War      40    Parvati Shallow          197
# 34   Survivor: Winners at War      40        Rob Mariano           55
# 143   Survivor: Game Changers      34       Cirie Fields          179
# 149   Survivor: Game Changers      34        Oscar Lusth          201
#
#        castaway  age         city        state personality_type  episode  day  \
# 32       Sandra   44    Riverview      Florida             ESTP        6   16
# 33      Parvati   36  Los Angeles   California             ENFJ        6   16
# 34   Boston Rob   43    Pensacola      Florida             ESTJ        5   14
# 143       Cirie   45      Norwalk  Connecticut             ENFJ       12   36
# 149        Ozzy   34       Venice   California             ISFP        7   24
#
#      order         result      jury_status original_tribe swapped_tribe  \
# 32       8  8th voted out              NaN          Dakal         Dakal
# 33       7  7th voted out  5th jury member           Sele          Sele
# 34       6  6th voted out  4th jury member           Sele          Yara
# 143     15     Eliminated  8th jury member           Nuku         Tavua
# 149      9  9th voted out  2nd jury member           Nuku         Tavua
#
#     swapped_tribe_2 merged_tribe  total_votes_received  immunity_idols_won
# 32              NaN          NaN                     1                   4
# 33              NaN          NaN                     5                   3
# 34              NaN          NaN                     4                   2
# 143             NaN    Maku Maku                     0                   4
# 149             NaN    Maku Maku                     6                   4

# %%
Q7 = pd.DataFrame({"castaway_id": castaways_df.loc[:,"castaway_id"],
                   "full_name": castaways_df.loc[:,"full_name"],
                   "total_days_played": days_dataframe.loc[:,"total_days_played"]}).sort_values(by = ["total_days_played"], ascending = False).reset_index(drop = True)
Q7
# Out:
#    castaway_id          full_name  total_days_played
# 0           55        Rob Mariano                131
# 1          197    Parvati Shallow                130
# 2          201        Oscar Lusth                128
# 3          179       Cirie Fields                121
# 4          112  Sandra Diaz-Twine                110

# %% [markdown]
# **Q8A & Q8B**: Using the `castaway_details` data, what is the percentage of total extroverts and introverts that have played the game (count players only once even if they have played in more than one season).  Do not count contestants without a personality type listed in your calculations.  Save these percentages as `Q8A` and `Q8B` respectively.  Note: Round all percentages to two decimal points and write as a float (example: 55.57).
#
# For more information on personality types check this [Wikipedia article](https://en.wikipedia.org/wiki/Myers%E2%80%93Briggs_Type_Indicator).

# %%
castaway_details_2 = castaway_details.copy()

# %%
castaway_details_3 = castaway_details_2.dropna(subset =["personality_type"])

# %%
castaway_details_3["personality_check"] = castaway_details_2["personality_type"].str.startswith("E")
castaway_details_3
# Out:
# /var/folders/86/hhnttg511rx7rjhk86mrn9700000gn/T/ipykernel_33662/3479136914.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   castaway_details_3["personality_check"] = castaway_details_2["personality_type"].str.startswith("E")
#      castaway_id          full_name short_name date_of_birth date_of_death  \
# 0              1  Sonja Christopher      Sonja    1937-01-28           NaT
# 1              2      B.B. Andersen       B.B.    1936-01-18    2013-10-29
# 2              3    Stacey Stillman     Stacey    1972-08-11           NaT
# 3              4        Ramona Gray     Ramona    1971-01-20           NaT
# 4              5          Dirk Been       Dirk    1976-06-15           NaT
# ..           ...                ...        ...           ...           ...
# 603          604      Tiffany Seely    Tiffany    1973-12-08           NaT
# 604          605       Sydney Segal     Sydney    1995-07-19           NaT
# 605          606      Shantel Smith       Shan    1987-03-11           NaT
# 606          607         David Voce       Voce    1986-05-01           NaT
# 607          608      Liana Wallace      Liana    2000-10-25           NaT
#
#      gender   race ethnicity             occupation personality_type  \
# 0    Female    NaN       NaN               Musician             ENFP
# 1      Male    NaN       NaN  Real Estate Developer             ESTJ
# 2    Female    NaN       NaN               Attorney             ENTJ
# 3    Female  Black       NaN     Biochemist/Chemist             ISTJ
# 4      Male    NaN       NaN           Dairy Farmer             ISFP
# ..      ...    ...       ...                    ...              ...
# 603  Female  White    Jewish                Teacher             ENTP
# 604  Female  White    Jewish            Law Student             ESTP
# 605  Female  Black       NaN                 Pastor             ENFJ
# 606    Male    NaN       NaN           Neurosurgeon             ENTJ
# 607  Female  Black    Jewish        College Student             ESTJ
#
#     personality_check
# 0                True
# 1                True
# 2                True
# 3               False
# 4               False
# ..                ...
# 603              True
# 604              True
# 605              True
# 606              True
# 607              True
#
# [606 rows x 11 columns]

# %%
castaway_details_3["personality_check"].value_counts()
# Out:
# True     325
# False    281
# Name: personality_check, dtype: int64

# %%
Q8A = round((len(castaway_details_3[castaway_details_3["personality_check"] == True])/len(castaway_details_3)*100),2)
Q8A
# Out:
# 53.63

# %%
Q8B = round((len(castaway_details_3[castaway_details_3["personality_check"] == False])/len(castaway_details_3)*100),2)
Q8B
# Out:
# 46.37

# %% [markdown]
# **Q9A & Q9B**: Now that we know the percentages of total players that are extroverted and introverted, let's see if that made a difference in terms of who actually won their season.
#
# What is the percentage of total extroverts and introverts that have won the game (count players only once even if they have won more than one season)?  Save these percentages as `Q9A` and `Q9B` respectively.  Note: Round all percentages to two decimal points and write as a float (example: 55.57).

# %%
sole_survivor.head()
# Out:
#                         season_name  season       full_name  castaway_id  \
# 0                  Survivor: Borneo       1   Richard Hatch           16
# 1  Survivor: The Australian Outback       2     Tina Wesson           32
# 2                  Survivor: Africa       3      Ethan Zohn           48
# 3               Survivor: Marquesas       4  Vecepia Towery           64
# 4                Survivor: Thailand       5    Brian Heidik           80
#
#   castaway  age         city          state personality_type  episode  day  \
# 0  Richard   39      Newport   Rhode Island             ENTP       14   39
# 1     Tina   40    Knoxville      Tennessee             ESFJ       16   42
# 2    Ethan   27    Lexington  Massachusetts             ISFP       15   39
# 3  Vecepia   36      Hayward     California             ISTJ       15   39
# 4    Brian   34  Quartz Hill     California             ISTP       15   39
#
#    order         result jury_status original_tribe swapped_tribe  \
# 0     16  Sole Survivor         NaN           Tagi           NaN
# 1     16  Sole Survivor         NaN         Ogakor           NaN
# 2     16  Sole Survivor         NaN          Boran         Boran
# 3     16  Sole Survivor         NaN        Maraamu          Rotu
# 4     16  Sole Survivor         NaN     Chuay Gahn           NaN
#
#   swapped_tribe_2 merged_tribe  total_votes_received  immunity_idols_won
# 0             NaN      Rattana                     6                   4
# 1             NaN   Barramundi                     0                   2
# 2             NaN    Moto Maji                     0                   4
# 3             NaN     Soliantu                     2                   4
# 4             NaN    Chuay Jai                     0                   8

# %%
sole_survivor_2 = sole_survivor.copy()

# %%
sole_survivor_2 = sole_survivor_2.drop_duplicates(subset =["full_name"])

# %%
sole_survivor_2["personality_check"] = sole_survivor_2["personality_type"].str.startswith("E")
sole_survivor_2
# Out:
#                                   season_name  season           full_name  \
# 0                            Survivor: Borneo       1       Richard Hatch
# 1            Survivor: The Australian Outback       2         Tina Wesson
# 2                            Survivor: Africa       3          Ethan Zohn
# 3                         Survivor: Marquesas       4      Vecepia Towery
# 4                          Survivor: Thailand       5        Brian Heidik
# 5                        Survivor: The Amazon       6       Jenna Morasca
# 6                     Survivor: Pearl Islands       7   Sandra Diaz-Twine
# 7                         Survivor: All-Stars       8        Amber Brkich
# 8                           Survivor: Vanuatu       9     Chris Daugherty
# 9                             Survivor: Palau      10         Tom Westman
# 10                        Survivor: Guatemala      11    Danni Boatwright
# 11                           Survivor: Panama      12     Aras Baskauskas
# 12                     Survivor: Cook Islands      13            Yul Kwon
# 13                             Survivor: Fiji      14           Earl Cole
# 14                            Survivor: China      15         Todd Herzog
# 15                       Survivor: Micronesia      16     Parvati Shallow
# 16                            Survivor: Gabon      17      Robert Crowley
# 17                        Survivor: Tocantins      18    James Thomas Jr.
# 18                            Survivor: Samoa      19       Natalie White
# 20                        Survivor: Nicaragua      21           Jud Birza
# 21                Survivor: Redemption Island      22         Rob Mariano
# 22                    Survivor: South Pacific      23       Sophie Clarke
# 23                        Survivor: One World      24        Kim Spradlin
# 24                      Survivor: Philippines      25      Denise Stapley
# 25                         Survivor: Caramoan      26        John Cochran
# 7              ISFP       17   39     18  Sole Survivor         NaN
# 8              ENTP       15   39     18  Sole Survivor         NaN
# 9              ESTJ       15   39     20  Sole Survivor         NaN
# 10             ENFJ       15   39     18  Sole Survivor         NaN
# 11             INFP       16   39     16  Sole Survivor         NaN
# 12             INTJ       16   39     20  Sole Survivor         NaN
# 13             INFJ       15   39     19  Sole Survivor         NaN
# 14             ENFP       15   39     16  Sole Survivor         NaN
# 15             ENFJ       15   39     20  Sole Survivor         NaN
# 16             INTP       14   39     18  Sole Survivor         NaN
# 17             ESTP       15   39     16  Sole Survivor         NaN
# 18             ISFJ       16   39     20  Sole Survivor         NaN
# 20             ESFP       16   39     20  Sole Survivor         NaN
# 21             ESTJ       15   39     20  Sole Survivor         NaN
# 22             INTJ       16   39     20  Sole Survivor         NaN
# 23             INFJ       15   39     18  Sole Survivor         NaN
# 24             INFJ       15   39     18  Sole Survivor         NaN
# 25             INTP       15   39     20  Sole Survivor         NaN
# 26             ESTP       15   39     23  Sole Survivor         NaN
# 27             ESTP       14   39     18  Sole Survivor         NaN
# 28             ESTP       15   39     18  Sole Survivor         NaN
# 29             ESTP       15   39     18  Sole Survivor         NaN
# 30             ESTJ       15   39     20  Sole Survivor         NaN
# 31             ESFP       15   39     18  Sole Survivor         NaN
# 32             ENTP       14   39     20  Sole Survivor         NaN
# 33             ENTJ       14   39     20  Sole Survivor         NaN
# 34             ESFP       14   39     18  Sole Survivor         NaN
# 35             INFJ       14   39     20  Sole Survivor         NaN
# 36             ENTP       14   39     20  Sole Survivor         NaN
# 37             ENTP       14   39     20  Sole Survivor         NaN
# 38             ENFJ       14   39     20  Sole Survivor         NaN
# 40             ENFP       13   26     18  Sole Survivor         NaN
#
#    original_tribe swapped_tribe swapped_tribe_2  merged_tribe  \
# 0            Tagi           NaN             NaN       Rattana
# 1          Ogakor           NaN             NaN    Barramundi
# 2           Boran         Boran             NaN     Moto Maji
# 3         Maraamu          Rotu             NaN      Soliantu
# 4      Chuay Gahn           NaN             NaN     Chuay Jai
# 5          Jaburu        Jaburu             NaN        Jacaré
# 6           Drake         Drake             NaN        Balboa
# 7         Chapera       Chapera         Chapera  Chaboga Mogo
# 8          Lopevi        Lopevi             NaN        Alinta
# 9           Koror           NaN             NaN         Koror
# 10          Nakúm         Yaxhá             NaN        Xhakúm
# 11        Viveros        Casaya             NaN       Gitanos
# 12      Puka Puka      Aitutaki        Aitutaki     Aitutonga
# 13           Ravu          Moto             NaN     Bula Bula
# 14       Fei Long      Fei Long             NaN   Hae Da Fung
# 15        Malakal         Airai             NaN          Dabu
# 16           Kota          Kota            Kota         Nobag
# 17        Jalapao           NaN             NaN         Forza
# 18        Foa Foa           NaN             NaN          Aiga
# 20        La Flor       La Flor             NaN      Libertad
# 21        Ometepe           NaN             NaN      Murlonio
# 22          Upolu           NaN             NaN       Te Tuna
# 23         Salani        Salani             NaN       Tikiano
# 24        Matsing       Kalabaw             NaN     Dangrayne
# 25          Bikal         Bikal             NaN     Enil Edam
# 26         Galang       Tadhana             NaN        Kasama
# 27         Aparri        Solana             NaN     Solarrion
# 28        Hunahpu       Hunahpu             NaN        Huyopa
# 29       Escameca      Escameca             NaN        Merica
# 30          Bayon         Bayon           Bayon         Orkun
# 31         Gondol      Chan Loh             NaN          Dara
# 32          Vanua        Takali             NaN        Vinaka
# 33           Nuku         Tavua             NaN     Maku Maku
# 34           Levu          Yawa             NaN        Solewa
# 35         Naviti        Naviti          Yanuya        Lavita
# 36          David        Jabeni             NaN      Kalokalo
# 37           Manu           NaN             NaN          Vata
# 38          Vokai         Vokai             NaN      Lumuwaku
# 40           Luvu           NaN             NaN      Via Kana
#
#     total_votes_received  immunity_idols_won  personality_check
# 0                      6                   4               True
# 1                      0                   2               True
# 2                      0                   4              False
# 3                      2                   4              False
# 4                      0                   8              False
# 5                      3                   7              False
# 6                      0                   3               True
# 7                      6                   6              False
# 8                      3                   6               True
# 9                      0                  12               True
# 10                     1                   5               True
# 11                     9                   4              False
# 12                     5                   6              False
# 13                     1                   5              False
# 14                     5                   4               True
# 15                     4                   7               True
# 16                     2                   8              False
# 17                     0                   5               True
# 18                     8                   1              False
# 20                     2                   8               True
# 21                     7                   9               True
# 22                     5                   6              False
# 23                     3                   6              False
# 24                     6                   1              False
# 25                     0                   7              False
# 26                     2                   8               True
# 27                     5                   6               True
# 28                     0                   6               True
# 29                     4                   7               True
# 30                     3                   7               True
# 31                     1                   7               True
# 32                     6                   6               True
# 33                     0                   4               True
# 34                    11                   4               True
# 35                     5                   8              False
# 36                     0                   4               True
# 37                     9                   1               True
# 38                     2                   6               True
# 40                     2                   8               True

# %%
Q9A = round((len(sole_survivor_2[sole_survivor_2["personality_check"] == True])/len(sole_survivor_2)*100),2)
Q9A
# Out:
# 61.54

# %%
Q9B = round((len(sole_survivor_2[sole_survivor_2["personality_check"] == False])/len(sole_survivor_2)*100),2)
Q9B
# Out:
# 38.46

# %% [markdown]
# **Q10:** Which contestants have never received a tribal council vote (i.e. a vote to be voted out of the game as shown in the `vote_id` column in the `vote_history` DataFrame)? Note that there are various reasons for a contestant to not receive a tribal vote: they quit, made it to the end, medical emergency, etc.  Select their rows from the `castaway_details` DataFrame and save this as `Q10` in ascending order by `castaway_id`.  This should return a DataFrame and the index and missing values should be left as is.

# %%
vote_history["vote_id"] = vote_history["vote_id"].fillna(0)
vote_history["vote_id"] = vote_history["vote_id"].astype(int)
Q10 = castaway_details[~castaway_details.castaway_id.isin(vote_history["vote_id"])].sort_values(by = ["castaway_id"])

# %% [markdown]
# **Q11:** What contestant has won the most number of challenges?  Select their row from the `castaway_details` DataFrame and save this as `Q11`.  This should return a DataFrame and the index and missing values should be left as is.

# %%
castaway_details.head()
# Out:
#    castaway_id          full_name short_name date_of_birth date_of_death  \
# 0            1  Sonja Christopher      Sonja    1937-01-28           NaT
# 1            2      B.B. Andersen       B.B.    1936-01-18    2013-10-29
# 2            3    Stacey Stillman     Stacey    1972-08-11           NaT
# 3            4        Ramona Gray     Ramona    1971-01-20           NaT
# 4            5          Dirk Been       Dirk    1976-06-15           NaT
#
#    gender   race ethnicity             occupation personality_type
# 0  Female    NaN       NaN               Musician             ENFP
# 1    Male    NaN       NaN  Real Estate Developer             ESTJ
# 2  Female    NaN       NaN               Attorney             ENTJ
# 3  Female  Black       NaN     Biochemist/Chemist             ISTJ
# 4    Male    NaN       NaN           Dairy Farmer             ISFP

# %%
challenge_results.head()
# Out:
#         season_name  season  episode  day  episode_title  challenge_name  \
# 0  Survivor: Borneo       1        1    3  The Marooning  Quest for Fire
# 1  Survivor: Borneo       1        1    3  The Marooning  Quest for Fire
# 2  Survivor: Borneo       1        1    3  The Marooning  Quest for Fire
# 3  Survivor: Borneo       1        1    3  The Marooning  Quest for Fire
# 4  Survivor: Borneo       1        1    3  The Marooning  Quest for Fire
#
#         challenge_type outcome_type challenge_id  winner_id    winner  \
# 0  Reward and Immunity       Tribal       CH0001        2.0      B.B.
# 1  Reward and Immunity       Tribal       CH0001        4.0    Ramona
# 2  Reward and Immunity       Tribal       CH0001        6.0      Joel
# 3  Reward and Immunity       Tribal       CH0001        7.0  Gretchen
# 4  Reward and Immunity       Tribal       CH0001        8.0      Greg
#
#   winning_tribe outcome_status
# 0        Pagong         Winner
# 1        Pagong         Winner
# 2        Pagong         Winner
# 3        Pagong         Winner
# 4        Pagong         Winner

# %%
challenge_grouped = challenge_results.groupby(["winner_id"])
challenge_grouped.count().sort_values(by = ["season_name"],ascending = False)
# Out:
#            season_name  season  episode  day  episode_title  challenge_name  \
# winner_id
# 201.0               42      42       42   42             42              42
# 55.0                37      37       37   37             37              37
# 197.0               34      34       34   34             34              34
# 451.0               33      33       33   33             33              33
# 333.0               31      31       31   31             31              31
# ...                ...     ...      ...  ...            ...             ...
# 573.0                1       1        1    1              1               1
# 574.0                1       1        1    1              1               1
# 575.0                1       1        1    1              1               1
# 284.0                1       1        1    1              1               1
# 480.0                1       1        1    1              1               1
#
#            challenge_type  outcome_type  challenge_id  winner  winning_tribe  \
# winner_id
# 201.0                  42            42            42      42             27
# 55.0                   37            37            37      37             24
# 197.0                  34            34            34      34             26
# 451.0                  33            33            33      33             22
# 333.0                  31            31            31      31             20
# ...                   ...           ...           ...     ...            ...
# 573.0                   1             1             1       1              1
# 574.0                   1             1             1       1              1
# 575.0                   1             1             1       1              1
# 284.0                   1             1             1       1              1
# 480.0                   1             1             1       1              1
#
#            outcome_status
# winner_id
# 201.0                  42
# 55.0                   37
# 197.0                  34
# 451.0                  33
# 333.0                  31
# ...                   ...
# 573.0                   1
# 574.0                   1
# 575.0                   1
# 284.0                   1
# 480.0                   1
#
# [564 rows x 12 columns]

# %%
challenge_results[challenge_results["winner_id"] == 201.0]
# Out:
#                   season_name  season  episode  day  \
# 1187   Survivor: Cook Islands      13        1    3
# 1192   Survivor: Cook Islands      13        1    3
# 1232   Survivor: Cook Islands      13        4   11
# 1240   Survivor: Cook Islands      13        4   11
# 1248   Survivor: Cook Islands      13        5   14
# 1264   Survivor: Cook Islands      13        6   15
# 1277   Survivor: Cook Islands      13        8   18
# 1281   Survivor: Cook Islands      13        9   21
# 1285   Survivor: Cook Islands      13        9   21
# 1289   Survivor: Cook Islands      13       10   24
# 1306      201.0   Ozzy           NaN         Winner
# 1307      201.0   Ozzy           NaN         Winner
# 1549      201.0   Ozzy       Malakal         Winner
# 1567      201.0   Ozzy       Malakal         Winner
# 1575      201.0   Ozzy       Malakal         Winner
# 1583      201.0   Ozzy       Malakal         Winner
# 1626      201.0   Ozzy       Malakal         Winner
# 1641      201.0   Ozzy           NaN         Winner
# 2306      201.0   Ozzy        Savaii         Winner
# 2311      201.0   Ozzy        Savaii         Winner
# 2327      201.0   Ozzy        Savaii         Winner
# 2342      201.0   Ozzy        Savaii         Winner
# 2357      201.0   Ozzy           NaN         Winner
# 2361      201.0   Ozzy           NaN         Winner
# 2365      201.0   Ozzy           NaN         Winner
# 2367      201.0   Ozzy           NaN         Winner
# 2370      201.0   Ozzy           NaN         Winner
# 2371      201.0   Ozzy           NaN         Winner
# 2373      201.0   Ozzy           NaN         Winner
# 3511      201.0   Ozzy          Nuku         Winner
# 3521      201.0   Ozzy          Nuku         Winner
# 3531      201.0   Ozzy          Nuku         Winner
# 3548      201.0   Ozzy         Tavua         Winner
# 3552      201.0   Ozzy         Tavua         Winner
# 3574      201.0   Ozzy         Tavua         Winner
# 3598      201.0   Ozzy          Nuku         Winner
# 3606      201.0   Ozzy           NaN         Winner

# %%
castaway_details_index = castaway_details[castaway_details["short_name"] == "Ozzy"]
castaway_details_index
# Out:
#      castaway_id    full_name short_name date_of_birth date_of_death gender  \
# 200          201  Oscar Lusth       Ozzy    1981-08-23           NaT   Male
#
#                  race           ethnicity           occupation  \
# 200  Mexican American  Hispanic or Latino  Waiter;Photographer
#
#     personality_type
# 200             ISFP

# %%
Q11 = castaway_details_index.iloc[[0]]
Q11
# Out:
#      castaway_id    full_name short_name date_of_birth date_of_death gender  \
# 200          201  Oscar Lusth       Ozzy    1981-08-23           NaT   Male
#
#                  race           ethnicity           occupation  \
# 200  Mexican American  Hispanic or Latino  Waiter;Photographer
#
#     personality_type
# 200             ISFP

# %% [markdown]
# **Q12:** Let's see how many winners ended up getting unanimous jury votes to win the game.  Create a Dataframe that shows the survivors that got unanimous jury votes with these columns in the final output: `season`, `season_name`, `winner_id`, `full_name`.  The DataFrame should be sorted by season and the index should go from 0 to n-1.  Save this as `Q12`.

# %%
jury_votes.head()
# Out:
#     season_name  season castaway finalist  vote  castaway_id  finalist_id
# 0  Survivor: 41      41  Heather  Deshawn     0          593          601
# 1  Survivor: 41      41   Ricard  Deshawn     0          596          601
# 2  Survivor: 41      41    Danny  Deshawn     1          599          601
# 3  Survivor: 41      41    Liana  Deshawn     0          608          601
# 4  Survivor: 41      41     Shan  Deshawn     0          606          601

# %%
jury_votes_grouped = jury_votes.groupby(["finalist","vote"])
jury_votes_2 = jury_votes_grouped.count().sort_values(by = ["vote","season_name"],ascending = False)
jury_votes_2
#smallest survivor jury is 7 so anyone with fewer 1s cannot be unanimous#
my_list = ["Tony","Natalie","Chris","Sandra","Boston Rob","Adam",'Jeremy','Earl','Mike',
           'Cochran','Parvati','Tommy','Erika','J.T.','Kim','Nick','Sarah','Tyson']
my_list
# Out:
# ['Tony',
#  'Natalie',
#  'Chris',
#  'Sandra',
#  'Boston Rob',
#  'Adam',
#  'Jeremy',
#  'Earl',
#  'Mike',
#  'Cochran',
#  'Parvati',
#  'Tommy',
#  'Erika',
#  'J.T.',
#  'Kim',
#  'Nick',
#  'Sarah',
#  'Tyson']

# %%
jury_votes_3 = jury_votes_2.loc[my_list]
jury_votes_3
# #look for finalists where no vote 0 [Adam, Jeremy, Earl, Cochran, J.T.]
unanimous_list = ["Adam", "Jeremy", "Earl", "Cochran", "J.T."]
unanimous_list
# Out:
# ['Adam', 'Jeremy', 'Earl', 'Cochran', 'J.T.']

# %%
jury_votes_merge = castaway_details.merge(jury_votes, left_on = "castaway_id", right_on = "finalist_id")
jury_votes_merge.head(5)
# Out:
#    castaway_id_x         full_name short_name date_of_birth date_of_death  \
# 0             10  Gervase Peterson    Gervase    1969-11-02           NaT
# 1             10  Gervase Peterson    Gervase    1969-11-02           NaT
# 2             10  Gervase Peterson    Gervase    1969-11-02           NaT
# 3             10  Gervase Peterson    Gervase    1969-11-02           NaT
# 4             10  Gervase Peterson    Gervase    1969-11-02           NaT
#
#   gender   race ethnicity                                occupation  \
# 0   Male  Black       NaN  YMCA Basketball Coach;Cigar Lounge Owner
# 1   Male  Black       NaN  YMCA Basketball Coach;Cigar Lounge Owner
# 2   Male  Black       NaN  YMCA Basketball Coach;Cigar Lounge Owner
# 3   Male  Black       NaN  YMCA Basketball Coach;Cigar Lounge Owner
# 4   Male  Black       NaN  YMCA Basketball Coach;Cigar Lounge Owner
#
#   personality_type                season_name  season castaway finalist  vote  \
# 0             ESTP  Survivor: Blood vs. Water      27     Aras  Gervase     0
# 1             ESTP  Survivor: Blood vs. Water      27    Caleb  Gervase     0
# 2             ESTP  Survivor: Blood vs. Water      27    Ciera  Gervase     0
# 3             ESTP  Survivor: Blood vs. Water      27   Hayden  Gervase     0
# 4             ESTP  Survivor: Blood vs. Water      27    Katie  Gervase     0
#
#    castaway_id_y  finalist_id
# 0            182           10
# 1            403           10
# 2            406           10
# 3            405           10
# 4            404           10

# %%
jury_votes_merge_2 = jury_votes_merge[(jury_votes_merge["short_name"] == "Adam") | (jury_votes_merge["short_name"] == "Jeremy") | (jury_votes_merge["short_name"] == "Earl") | (jury_votes_merge["short_name"] == "Cochran") | (jury_votes_merge["short_name"] == "J.T.")]
jury_votes_merge_2
# Out:
#      castaway_id_x         full_name short_name date_of_birth date_of_death  \
# 264            221         Earl Cole       Earl    1971-04-09           NaT
# 265            221         Earl Cole       Earl    1971-04-09           NaT
# 266            221         Earl Cole       Earl    1971-04-09           NaT
# 267            221         Earl Cole       Earl    1971-04-09           NaT
# 268            221         Earl Cole       Earl    1971-04-09           NaT
# 269            221         Earl Cole       Earl    1971-04-09           NaT
# 270            221         Earl Cole       Earl    1971-04-09           NaT
# 271            221         Earl Cole       Earl    1971-04-09           NaT
# 272            221         Earl Cole       Earl    1971-04-09           NaT
# 347            281  James Thomas Jr.       J.T.    1984-06-23           NaT
# 348            281  James Thomas Jr.       J.T.    1984-06-23           NaT
# 349            281  James Thomas Jr.       J.T.    1984-06-23           NaT
# 350            281  James Thomas Jr.       J.T.    1984-06-23           NaT
# 351            281  James Thomas Jr.       J.T.    1984-06-23           NaT
# 352            281  James Thomas Jr.       J.T.    1984-06-23           NaT
# 353            281  James Thomas Jr.       J.T.    1984-06-23           NaT
# 443            348      John Cochran    Cochran    1987-01-17           NaT
# 444            348      John Cochran    Cochran    1987-01-17           NaT
# 445            348      John Cochran    Cochran    1987-01-17           NaT
# 446            348      John Cochran    Cochran    1987-01-17           NaT
# 447            348      John Cochran    Cochran    1987-01-17           NaT
# 448            348      John Cochran    Cochran    1987-01-17           NaT
# 449            348      John Cochran    Cochran    1987-01-17           NaT
# 450            348      John Cochran    Cochran    1987-01-17           NaT
# 612            433    Jeremy Collins     Jeremy    1978-04-16           NaT
# 613            433    Jeremy Collins     Jeremy    1978-04-16           NaT
# 614            433    Jeremy Collins     Jeremy    1978-04-16           NaT
# 615            433    Jeremy Collins     Jeremy    1978-04-16           NaT
# 616            433    Jeremy Collins     Jeremy    1978-04-16           NaT
# 617            433    Jeremy Collins     Jeremy    1978-04-16           NaT
# 618            433    Jeremy Collins     Jeremy    1978-04-16           NaT
# 619            433    Jeremy Collins     Jeremy    1978-04-16           NaT
# 620            433    Jeremy Collins     Jeremy    1978-04-16           NaT
# 621            433    Jeremy Collins     Jeremy    1978-04-16           NaT
# 743            498        Adam Klein       Adam    1991-01-15           NaT
# 744            498        Adam Klein       Adam    1991-01-15           NaT
# 745            498        Adam Klein       Adam    1991-01-15           NaT
# 746            498        Adam Klein       Adam    1991-01-15           NaT
# 747            498        Adam Klein       Adam    1991-01-15           NaT
# 748            498        Adam Klein       Adam    1991-01-15           NaT
# 749            498        Adam Klein       Adam    1991-01-15           NaT
# 750            498        Adam Klein       Adam    1991-01-15           NaT
# 751            498        Adam Klein       Adam    1991-01-15           NaT
# 752            498        Adam Klein       Adam    1991-01-15           NaT
#
#     gender   race ethnicity  \
# 264   Male  Black       NaN
# 265   Male  Black       NaN
# 266   Male  Black       NaN
# 267   Male  Black       NaN
# 268   Male  Black       NaN
# 269   Male  Black       NaN
# 270   Male  Black       NaN
# 271   Male  Black       NaN
# 272   Male  Black       NaN
# 347   Male    NaN       NaN
# 348   Male    NaN       NaN
# 349   Male    NaN       NaN
# 350   Male    NaN       NaN
# 351   Male    NaN       NaN
# 352   Male    NaN       NaN
# 353   Male    NaN       NaN
# 443   Male  White    Jewish
# 444   Male  White    Jewish
# 445   Male  White    Jewish
# 446   Male  White    Jewish
# 447   Male  White    Jewish
# 448   Male  White    Jewish
# 449   Male  White    Jewish
# 450   Male  White    Jewish
# 612   Male  Black       NaN
# 613   Male  Black       NaN
# 614   Male  Black       NaN
# 615   Male  Black       NaN
# 616   Male  Black       NaN
# 617   Male  Black       NaN
# 618   Male  Black       NaN
# 619   Male  Black       NaN
# 620   Male  Black       NaN
# 621   Male  Black       NaN
# 743   Male  White    Jewish
# 744   Male  White    Jewish
# 745   Male  White    Jewish
# 746   Male  White    Jewish
# 747   Male  White    Jewish
# 748   Male  White    Jewish
# 749   Male  White    Jewish
# 750   Male  White    Jewish
# 751   Male  White    Jewish
# 752   Male  White    Jewish
#
#                                             occupation personality_type  \
# 264                                       Ad Executive             INFJ
# 265                                       Ad Executive             INFJ
# 266                                       Ad Executive             INFJ
# 267                                       Ad Executive             INFJ
# 268                                       Ad Executive             INFJ
# 269                                       Ad Executive             INFJ
# 270                                       Ad Executive             INFJ
# 271                                       Ad Executive             INFJ
# 272                                       Ad Executive             INFJ
# 347                                     Cattle Rancher             ESTP
# 348                                     Cattle Rancher             ESTP
# 349                                     Cattle Rancher             ESTP
# 350                                     Cattle Rancher             ESTP
# 351                                     Cattle Rancher             ESTP
# 352                                     Cattle Rancher             ESTP
# 353                                     Cattle Rancher             ESTP
# 443                                Harvard Law Student             INTP
# 444                                Harvard Law Student             INTP
# 445                                Harvard Law Student             INTP
# 446                                Harvard Law Student             INTP
# 447                                Harvard Law Student             INTP
# 448                                Harvard Law Student             INTP
# 449                                Harvard Law Student             INTP
# 450                                Harvard Law Student             INTP
# 612                              Cambridge Firefighter             ESTJ
# 613                              Cambridge Firefighter             ESTJ
# 614                              Cambridge Firefighter             ESTJ
# 615                              Cambridge Firefighter             ESTJ
# 616                              Cambridge Firefighter             ESTJ
# 617                              Cambridge Firefighter             ESTJ
# 618                              Cambridge Firefighter             ESTJ
# 619                              Cambridge Firefighter             ESTJ
# 620                              Cambridge Firefighter             ESTJ
# 621                              Cambridge Firefighter             ESTJ
# 743  Homeless Shelter Manager;Keynote Speaker and Host             ENTP
# 744  Homeless Shelter Manager;Keynote Speaker and Host             ENTP
# 745  Homeless Shelter Manager;Keynote Speaker and Host             ENTP
# 746  Homeless Shelter Manager;Keynote Speaker and Host             ENTP
# 747  Homeless Shelter Manager;Keynote Speaker and Host             ENTP
# 748  Homeless Shelter Manager;Keynote Speaker and Host             ENTP
# 749  Homeless Shelter Manager;Keynote Speaker and Host             ENTP
# 750  Homeless Shelter Manager;Keynote Speaker and Host             ENTP
# 751  Homeless Shelter Manager;Keynote Speaker and Host             ENTP
# 752  Homeless Shelter Manager;Keynote Speaker and Host             ENTP
#
#                          season_name  season   castaway finalist  vote  \
# 264                   Survivor: Fiji      14       Alex     Earl     1
# 265                   Survivor: Fiji      14        Boo     Earl     1
# 266                   Survivor: Fiji      14    Edgardo     Earl     1
# 267                   Survivor: Fiji      14       Lisi     Earl     1
# 268                   Survivor: Fiji      14   Michelle     Earl     1
# 269                   Survivor: Fiji      14     Mookie     Earl     1
# 270                   Survivor: Fiji      14      Rocky     Earl     1
# 271                   Survivor: Fiji      14      Stacy     Earl     1
# 272                   Survivor: Fiji      14    Yau-Man     Earl     1
# 347              Survivor: Tocantins      18    Brendan     J.T.     1
# 348              Survivor: Tocantins      18      Coach     J.T.     1
# 349              Survivor: Tocantins      18     Debbie     J.T.     1
# 350              Survivor: Tocantins      18      Erinn     J.T.     1
# 351              Survivor: Tocantins      18     Sierra     J.T.     1
# 352              Survivor: Tocantins      18        Taj     J.T.     1
# 353              Survivor: Tocantins      18      Tyson     J.T.     1
# 443               Survivor: Caramoan      26     Andrea  Cochran     1
# 444               Survivor: Caramoan      26     Brenda  Cochran     1
# 445               Survivor: Caramoan      26      Eddie  Cochran     1
# 446               Survivor: Caramoan      26       Erik  Cochran     1
# 447               Survivor: Caramoan      26    Malcolm  Cochran     1
# 448               Survivor: Caramoan      26    Michael  Cochran     1
# 449               Survivor: Caramoan      26    Phillip  Cochran     1
# 450               Survivor: Caramoan      26    Reynold  Cochran     1
# 612               Survivor: Cambodia      31  Abi-Maria   Jeremy     1
# 613               Survivor: Cambodia      31     Andrew   Jeremy     1
# 614               Survivor: Cambodia      31      Ciera   Jeremy     1
# 615               Survivor: Cambodia      31        Joe   Jeremy     1
# 616               Survivor: Cambodia      31       Kass   Jeremy     1
# 617               Survivor: Cambodia      31      Keith   Jeremy     1
# 618               Survivor: Cambodia      31     Kelley   Jeremy     1
# 619               Survivor: Cambodia      31      Kelly   Jeremy     1
# 620               Survivor: Cambodia      31      Kimmi   Jeremy     1
# 621               Survivor: Cambodia      31    Stephen   Jeremy     1
# 743  Survivor: Millennials vs. Gen X      33       Bret     Adam     1
# 744  Survivor: Millennials vs. Gen X      33      Chris     Adam     1
# 745  Survivor: Millennials vs. Gen X      33      David     Adam     1
# 746  Survivor: Millennials vs. Gen X      33        Jay     Adam     1
# 747  Survivor: Millennials vs. Gen X      33    Jessica     Adam     1
# 748  Survivor: Millennials vs. Gen X      33   Michelle     Adam     1
# 749  Survivor: Millennials vs. Gen X      33     Sunday     Adam     1
# 750  Survivor: Millennials vs. Gen X      33     Taylor     Adam     1
# 751  Survivor: Millennials vs. Gen X      33       Will     Adam     1
# 752  Survivor: Millennials vs. Gen X      33       Zeke     Adam     1
#
#      castaway_id_y  finalist_id
# 264            215          221
# 265            217          221
# 266            213          221
# 267            211          221
# 268            212          221
# 269            214          221
# 270            210          221
# 271            216          221
# 272            218          221
# 347            273          281
# 348            277          281
# 349            276          281
# 350            279          281
# 351            275          281
# 352            278          281
# 353            274          281
# 443            333          348
# 444            312          348
# 445            395          348
# 446            246          348
# 447            384          348
# 448            393          348
# 449            337          348
# 450            394          348
# 612            383          433
# 613            105          433
# 614            406          433
# 615            451          433
# 616            422          433
# 617            439          433
# 618            429          433
# 619             15          433
# 620             21          433
# 621            280          433
# 743            494          498
# 744            488          498
# 745            495          498
# 746            493          498
# 747            489          498
# 748            486          498
# 749            492          498
# 750            487          498
# 751            491          498
# 752            490          498

# %%
jury_votes_merge_3 = jury_votes_merge_2[["season","season_name","castaway_id_x","full_name"]].drop_duplicates(["full_name"]).reset_index(drop = True)
Q12 = jury_votes_merge_3.rename(columns = {"castaway_id_x":"winner_id"})
Q12
# Out:
#    season                      season_name  winner_id         full_name
# 0      14                   Survivor: Fiji        221         Earl Cole
# 1      18              Survivor: Tocantins        281  James Thomas Jr.
# 2      26               Survivor: Caramoan        348      John Cochran
# 3      31               Survivor: Cambodia        433    Jeremy Collins
# 4      33  Survivor: Millennials vs. Gen X        498        Adam Klein

# %% [markdown]
# **Q13:** For the `castaway_details` DataFrame, there is a `full_name` column and a `short_name` column.  It would be helpful for future analysis to have the contestants first and last name split into separate columns.  First copy the `castaway_details` DataFrame to a new DataFrame called `Q13` so that we do not change the original DataFrame.
#
# Create two new columns and add the contestant's first name to a new column called `first_name` and their last name to a new column called `last_name`.  Add these columns to the `Q13` DataFrame.  Put the `first_name` and `last_name` columns between the `full_name` and `short_name` columns.
#
# Note:  Be careful as some players have last names with multiple spaces.  For example, `Lex van den Berghe`.  You should code `Lex` as his first name and `van den Berghe` as his last name.

# %%
castaway_details_names = castaway_details.copy() 
castaway_details_names['first_name'] = castaway_details_names.full_name.str.split(" ",expand = True)[0]
castaway_details_names['last_name'] = castaway_details_names.full_name.str.split(" ",expand = True)[1]
Q13 = castaway_details_names[["castaway_id","full_name","first_name","last_name","short_name","date_of_birth","date_of_death","gender","race","ethnicity","occupation","personality_type"]]

# %% [markdown]
# **Q14:** Let's say that we wanted to predict a contestants personality type based on the information in the data files.  Your task is to create a DataFrame that lists the `castaway_id`, `full_name` and `personality_type` for each castaway contestant.  However, since most machine learning algorithms use numeric data, you want to change the personality types to the following numbers:
# - ISTJ - 1
# - ISTP - 2
# - ISFJ - 3
# - ISFP - 4
# - INFJ - 5
# - INFP - 6
# - INTJ - 7
# - INTP - 8
# - ESTP - 9
# - ESTJ - 10
# - ESFP - 11
# - ESFJ - 12
# - ENFP - 13
# - ENFJ - 14
# - ENTP - 15
# - ENTJ - 16
# - Missing values - 17
#
# Save this new DataFrame as `Q14` and sort based on `castaway_id` in ascending order.

# %%
castaway_details_code = castaway_details.copy()
castaway_details_code

code_to_num = {"ISTJ":"1",
"ISTP": "2",
"ISFJ": "3",
"ISFP": "4",
"INFJ": "5",
"INFP": "6",
"INTJ": "7",
"INTP": "8",
"ESTP": "9",
"ESTJ": "10",
"ESFP": "11",
"ESFJ": "12",
"ENFP": "13",
"ENFJ": "14",
"ENTP": "15",
"ENTJ": "16",
"NaN": "17"
}

code_to_num

castaway_details_code["personality_type"] = castaway_details_code["personality_type"].map(code_to_num)
Q14 = castaway_details_code[["castaway_id", "full_name", "personality_type"]]

# %% [markdown]
# **Q15:** After thinking about this some more, you realize that you don't want to code the personality traits as you did in problem 14 since the data is not ordinal.  Some machine learning algorithms will assume that numbers close to each other are more alike than those that are away from each other and that is not the case with these personality types.
#
# Let's create a new DataFrame called `Q15` that creates dummy columns (using `get_dummies`) for the original personality type column.  Add a prefix called "type" and drop the first column to help prevent multicollinearity.  The columns should be `castaway_id`, `full_name` followed by the various dummy columns for the personality types.  Don't worry about any missing values in this step.
#
# Remember: Don't change any of the original DataFrames or CodeGrade will not work correctly for this assignment.  Make sure you use `copy()` if needed.

# %%
# pd.get_dummies(ser, prefix='type')
castaway_details_dummy = castaway_details.copy()
castaway_details_dummy = pd.get_dummies(castaway_details_dummy, columns = ["personality_type"], prefix='type',drop_first=True)
Q15 = castaway_details_dummy.drop(columns =["short_name","date_of_birth","date_of_death","gender","race","ethnicity","occupation"])

# %% [markdown]
# **Q16:** After running your data above through your machine learning model, you determine that a better prediction might come from breaking the personality type into its four parts (one part for each character in the type).  Your task is now to create a DataFrame called `Q16` that splits the personality type into the various parts and creates a new column for each part (these columns should be called `interaction` that will represent the first letter in the personality type, `information` for the second letter, `decision` for the third, and `organization` for the fourth).
#
# Again, since most machine learning algorithms work with numeric data, perform the following on the four new columns:
# - `interaction` --> code all `I`'s as `0` and `E`'s as `1`
# - `information` --> code all `S`'s as `0` and `N`'s as `1`
# - `decision` --> code all `T`'s as `0` and `F`'s as `1`
# - `organization` --> code as `J`'s with `0` and `P`'s as `1`
# - Any missing values should be coded with a `2`
# - Double check that all of the above columns are an integer type.  Some students have a problem with CodeGrade because one of their columns ends up being a string instead of an int.
#
# For example, if a contestant's personality type was `ENTJ`, your columns for that row would be:
# - `1` for `interaction` because of the `E`
# - `1` for `information` because of the `N`
# - `0` for `decision` because of the `T`
# - `0` for `organization` because of the `J`
#
# The new DataFrame should be sorted in `castaway_id` order and have the following columns in this order: `castaway_id`, `full_name`, `personality_type`, `interaction`, `information`, `decision`, `organization`.
#
# Remember: Don't change any of the original DataFrames or CodeGrade will not work correctly for this assignment.  Make sure you use `copy()` if needed.

# %%
Q16a = castaway_details.copy()
Q16a["interaction"] = Q16a.loc[:,"personality_type"].str[0]
Q16a["information"] = Q16a.loc[:,"personality_type"].str[1]
Q16a["decision"] = Q16a.loc[:,"personality_type"].str[2]
Q16a["organization"] = Q16a.loc[:,"personality_type"].str[3]

code_to_num2 = {"I":"0",
"E": "1",
"S": "0",
"N": "1",
"F": "1",
"T": "0",
"J": "0",
"P": "1",}

code_to_num2

Q16a["interaction"] = Q16a["interaction"].map(code_to_num2)
Q16a["information"] = Q16a["information"].map(code_to_num2) 
Q16a["decision"] = Q16a["decision"].map(code_to_num2) 
Q16a["organization"] = Q16a["organization"].map(code_to_num2)


Q16a = Q16a[["castaway_id", "full_name", "personality_type", "interaction", "information", "decision", "organization"]]


Q16b = Q16a.fillna(2)
Q16b["interaction"] = Q16b["interaction"].astype(int)
Q16b["information"] = Q16b["information"].astype(int)
Q16b["decision"] = Q16b["decision"].astype(int)
Q16b["organization"] = Q16b["organization"].astype(int)
Q16b = Q16b.sort_values(by = ["castaway_id"])

Q16 = Q16b.reset_index(drop = True)
Q16
# Out:
#      castaway_id          full_name personality_type  interaction  \
# 0              1  Sonja Christopher             ENFP            1
# 1              2      B.B. Andersen             ESTJ            1
# 2              3    Stacey Stillman             ENTJ            1
# 3              4        Ramona Gray             ISTJ            0
# 4              5          Dirk Been             ISFP            0
# ..           ...                ...              ...          ...
# 603          604      Tiffany Seely             ENTP            1
# 604          605       Sydney Segal             ESTP            1
# 605          606      Shantel Smith             ENFJ            1
# 606          607         David Voce             ENTJ            1
# 607          608      Liana Wallace             ESTJ            1
#
#      information  decision  organization
# 0              1         1             1
# 1              0         0             0
# 2              1         0             0
# 3              0         0             0
# 4              0         1             1
# ..           ...       ...           ...
# 603            1         0             1
# 604            0         0             1
# 605            1         1             0
# 606            1         0             0
# 607            0         0             0
#
# [608 rows x 7 columns]

# %% [markdown]
# **Q17:** Using data from `castaways`, create a DataFrame called `Q17` that bins the contestant ages (their age when they were on the season, not their current age) into the following age categories:
# - 18-24
# - 25-34
# - 35-44
# - 45-54
# - 55-64
# - 65+
#
# The final DataFrame should have the following columns in this order: `season`, `castaway_id`, `full_name`, `age`, and `age_category`.  The DataFrame should be sorted by age and then castaway_id.  The index should be 0 through n-1.  You should have the same amount of rows as in the `castaways` DataFrame.
#
# Remember: Don't change any of the original DataFrames or CodeGrade will not work correctly for this assignment.  Make sure you use `copy()` if needed.

# %%
castaway_details.head()

# castaway_details_merge_2["age_at_season"] = (castaway_details_merge_2["filming_started"] - castaway_details_merge_2["date_of_birth"]).dt.days
# Out:
#    castaway_id          full_name short_name date_of_birth date_of_death  \
# 0            1  Sonja Christopher      Sonja    1937-01-28           NaT
# 1            2      B.B. Andersen       B.B.    1936-01-18    2013-10-29
# 2            3    Stacey Stillman     Stacey    1972-08-11           NaT
# 3            4        Ramona Gray     Ramona    1971-01-20           NaT
# 4            5          Dirk Been       Dirk    1976-06-15           NaT
#
#    gender   race ethnicity             occupation personality_type
# 0  Female    NaN       NaN               Musician             ENFP
# 1    Male    NaN       NaN  Real Estate Developer             ESTJ
# 2  Female    NaN       NaN               Attorney             ENTJ
# 3  Female  Black       NaN     Biochemist/Chemist             ISTJ
# 4    Male    NaN       NaN           Dairy Farmer             ISFP

# %%
castaway_details.shape
# Out:
# (608, 10)

# %%
castaways.head()
# Out:
#     season_name  season        full_name  castaway_id castaway  age  \
# 0  Survivor: 41      41  Erika Casupanan          594    Erika   32
# 1  Survivor: 41      41   Deshawn Radden          601  Deshawn   26
# 2  Survivor: 41      41  Xander Hastings          597   Xander   20
# 3  Survivor: 41      41   Heather Aldret          593  Heather   52
# 4  Survivor: 41      41      Ricard Foye          596   Ricard   31
#
#             city           state personality_type  episode  day  order  \
# 0        Toronta         Ontario             ENFP       13   26     18
# 1          Miami         Florida             ENTP       13   26     17
# 2        Chicago        Illinois             INFJ       13   26     16
# 3     Charleston  South Carolina             ISFJ       13   25     15
# 4  Sedro-Woolley      Washington             ENTJ       13   24     14
#
#            result      jury_status original_tribe swapped_tribe  \
# 0   Sole Survivor              NaN           Luvu           NaN
# 1       Runner-up              NaN           Luvu           NaN
# 2   2nd runner-up              NaN           Yase           NaN
# 3  15th voted out  8th jury member           Luvu           NaN
# 4  14th voted out  7th jury member             Ua           NaN
#
#   swapped_tribe_2 merged_tribe  total_votes_received  immunity_idols_won
# 0             NaN     Via Kana                     2                   8
# 1             NaN     Via Kana                     7                   6
# 2             NaN     Via Kana                     2                   6
# 3             NaN     Via Kana                     4                   6
# 4             NaN     Via Kana                     9                   5

# %%
castaways.shape
# Out:
# (762, 20)

# %%
season_summary
# Out:
#                                   season_name  season  \
# 0                            Survivor: Borneo       1
# 1            Survivor: The Australian Outback       2
# 2                            Survivor: Africa       3
# 3                         Survivor: Marquesas       4
# 4                          Survivor: Thailand       5
# 5                        Survivor: The Amazon       6
# 6                     Survivor: Pearl Islands       7
# 7                         Survivor: All-Stars       8
# 8                           Survivor: Vanuatu       9
# 9                             Survivor: Palau      10
# 10                        Survivor: Guatemala      11
# 11                           Survivor: Panama      12
# 12                     Survivor: Cook Islands      13
# 13                             Survivor: Fiji      14
# 14                            Survivor: China      15
# 15                       Survivor: Micronesia      16
# 16                            Survivor: Gabon      17
# 17                        Survivor: Tocantins      18
# 18                            Survivor: Samoa      19
# 19              Survivor: Heroes vs. Villains      20
# 20                        Survivor: Nicaragua      21
# 21                Survivor: Redemption Island      22
# 22                    Survivor: South Pacific      23
# 23                        Survivor: One World      24
# 24                      Survivor: Philippines      25
# 25                         Survivor: Caramoan      26
# 26                  Survivor: Blood vs. Water      27
# 27                          Survivor: Cagayan      28
# 28                 Survivor: San Juan del Sur      29
# 29                     Survivor: Worlds Apart      30
# 30                         Survivor: Cambodia      31
# 31                        Survivor: Kaoh Rong      32
# 32            Survivor: Millennials vs. Gen X      33
# 33                    Survivor: Game Changers      34
# 34  Survivor: Heroes vs. Healers vs. Hustlers      35
# 35                     Survivor: Ghost Island      36
# 36                Survivor: David vs. Goliath      37
# 37               Survivor: Edge of Extinction      38
# 38              Survivor: Island of the Idols      39
# 39                   Survivor: Winners at War      40
# 40                               Survivor: 41      41
#
#                                              location      country  \
# 0                         Pulau Tiga, Sabah, Malaysia     Malaysia
# 1   Herbert River at Goshen Station, Queensland, A...    Australia
# 2                       Shaba National Reserve, Kenya        Kenya
# 3      Nuku Hiva, Marquesas Islands, French Polynesia    Polynesia
# 4                Ko Tarutao, Satun Province, Thailand     Thailand
# 5                         Rio Negro, Amazonas, Brazil       Brazil
# 6                               Pearl Islands, Panama       Panama
# 7                               Pearl Islands, Panama       Panama
# 8                               Efate, Shefa, Vanuatu      Vanuatu
# 9                                        Koror, Palau        Palau
# 10  Laguna Yaxha, Yaxha-Nakum-Naranjo National Par...    Guatemala
# 11                              Pearl Islands, Panama       Panama
# 12                             Aitutaki, Cook Islands      Islands
# 13                          Macuata, Vanua Levu, Fiji         Fiji
# 14                   Zhelin, Jiujiang, Jiangxi, China        China
# 15                                       Koror, Palau        Palau
# 16  Wonga-Wongue Presidential Reserve, Estuaire, G...        Gabon
# 17                         Jalapao, Tocantins, Brazil       Brazil
# 18                                       Upolu, Samoa        Samoa
# 19                                       Upolu, Samoa        Samoa
# 20                 San Juan del Sur, Rivas, Nicaragua    Nicaragua
# 21                 San Juan del Sur, Rivas, Nicaragua    Nicaragua
# 22                 San Juan del Sur, Rivas, Nicaragua    Nicaragua
# 23                 San Juan del Sur, Rivas, Nicaragua    Nicaragua
# 24               Caramoan, Camarines Sur, Philippines  Philippines
# 25               Caramoan, Camarines Sur, Philippines  Philippines
# 26     Palaui Island, Santa Ana, Cagayan, Philippines  Philippines
# 27     Palaui Island, Santa Ana, Cagayan, Philippines  Philippines
# 28                 San Juan del Sur, Rivas, Nicaragua    Nicaragua
# 29                 San Juan del Sur, Rivas, Nicaragua    Nicaragua
# 30                                 Koh Rong, Cambodia     Cambodia
# 31                                 Koh Rong, Cambodia     Cambodia
# 32                             Mamanuca Islands, Fiji         Fiji
# 33                             Mamanuca Islands, Fiji         Fiji
# 34                             Mamanuca Islands, Fiji         Fiji
# 8             20.06           19.72            15.23         19.64  10.0
# 9             23.66           20.80            15.23         20.91   5.0
# 10            18.41           21.18            15.21         18.30   8.0
# 11            19.20           17.07            15.21         16.82  11.0
# 12            18.00           16.42            13.53         15.75  13.0
# 13            16.68           13.63            13.53         14.83  15.0
# 14            15.35           15.10            12.22         15.18   8.0
# 15            14.02           12.92            12.22         13.61  11.0
# 16            13.05           13.77            11.74         13.81  15.0
# 17            13.63           12.94            11.74         12.86  19.0
# 18            11.66           13.97            11.68         12.34  17.0
# 19            14.15           13.46            11.68         12.60  14.0
# 20            12.23           13.58            11.19         13.61  11.0
# 21            11.17           13.30            10.97         12.59  18.0
# 22            10.74           13.07             9.92         12.77  18.0
# 23            10.79           10.34             9.92         11.64  26.0
# 24            11.37           11.46             8.77         11.85  21.0
# 25             8.94           10.16             8.77         10.82  28.0
# 26             9.73           10.19             7.46         11.30  25.0
# 27             9.40            9.58             7.46         11.30  25.0
# 28             9.75            9.79             7.31         11.35  31.0
# 29            10.04            9.74             7.31         11.35  31.0
# 30             9.70            9.45             6.49         10.99  26.0
# 31             8.30            9.54             6.49         10.99  26.0
# 32             9.46            9.09             6.40         10.32  24.0
# 33             7.64            8.48             6.40         10.32  24.0
# 34             8.33            8.70             5.97         10.28  25.0
# 35             8.19            7.31             5.97         10.28  25.0
# 36             7.83            7.72             5.17          9.43  32.0
# 37             7.75            7.21             5.17          9.43  32.0
# 38             6.29            6.52             4.61           NaN   NaN
# 39             6.68            7.94             4.61           NaN   NaN
# 40             6.25            5.82             4.00           NaN   NaN

# %%
castaways
# Out:
#           season_name  season          full_name  castaway_id castaway  age  \
# 0        Survivor: 41      41    Erika Casupanan          594    Erika   32
# 1        Survivor: 41      41     Deshawn Radden          601  Deshawn   26
# 2        Survivor: 41      41    Xander Hastings          597   Xander   20
# 3        Survivor: 41      41     Heather Aldret          593  Heather   52
# 4        Survivor: 41      41        Ricard Foye          596   Ricard   31
# ..                ...     ...                ...          ...      ...  ...
# 757  Survivor: Borneo       1          Dirk Been            5     Dirk   23
# 758  Survivor: Borneo       1        Ramona Gray            4   Ramona   29
# 759  Survivor: Borneo       1    Stacey Stillman            3   Stacey   27
# 760  Survivor: Borneo       1      B.B. Andersen            2     B.B.   64
# 761  Survivor: Borneo       1  Sonja Christopher            1    Sonja   63
#
#               city           state personality_type  episode  day  order  \
# 0          Toronta         Ontario             ENFP       13   26     18
# 1            Miami         Florida             ENTP       13   26     17
# 2          Chicago        Illinois             INFJ       13   26     16
# 3       Charleston  South Carolina             ISFJ       13   25     15
# 4    Sedro-Woolley      Washington             ENTJ       13   24     14
# ..             ...             ...              ...      ...  ...    ...
# 757   Spring Green       Wisconsin             ISFP        5   15      5
# 758         Edison      New Jersey             ISTJ        4   12      4
# 759  San Francisco      California             ENTJ        3    9      3
# 760  Mission Hills          Kansas             ESTJ        2    6      2
# 761   Walnut Creek      California             ENFP        1    3      1
#
#              result      jury_status original_tribe swapped_tribe  \
# 0     Sole Survivor              NaN           Luvu           NaN
# 1         Runner-up              NaN           Luvu           NaN
# 2     2nd runner-up              NaN           Yase           NaN
# 3    15th voted out  8th jury member           Luvu           NaN
# 4    14th voted out  7th jury member             Ua           NaN
# ..              ...              ...            ...           ...
# 757   5th voted out              NaN           Tagi           NaN
# 758   4th voted out              NaN         Pagong           NaN
# 759   3rd voted out              NaN           Tagi           NaN
# 760   2nd voted out              NaN         Pagong           NaN
# 761   1st voted out              NaN           Tagi           NaN
#
#     swapped_tribe_2 merged_tribe  total_votes_received  immunity_idols_won
# 0               NaN     Via Kana                     2                   8
# 1               NaN     Via Kana                     7                   6
# 2               NaN     Via Kana                     2                   6
# 3               NaN     Via Kana                     4                   6
# 4               NaN     Via Kana                     9                   5
# ..              ...          ...                   ...                 ...
# 757             NaN          NaN                     4                   2
# 758             NaN          NaN                     6                   2
# 759             NaN          NaN                     6                   1
# 760             NaN          NaN                     6                   1
# 761             NaN          NaN                     4                   0
#
# [762 rows x 20 columns]

# %%
castaway_details_merge_3 = castaways.copy()
# castaway_details_merge_3["age_at_season"] = (castaway_details_merge_3["premiered"] - castaway_details_merge_2["date_of_birth"]).dt.days
# castaway_details_merge_3["years_old"] = castaway_details_merge_3["age_at_season"] / 365
castaway_details_merge_3

castaway_details_merge_3["age_category"] = pd.cut(x = castaway_details_merge_3['age'],
                                bins = [17,24,34,44,54,65,122],
                                labels=["18-24", "25-34", "35-44", "45-54", "55-64", "65+"]) 


# castaway_details_merge_3 = castaway_details_merge_3.rename(columns = {"castaway_id_x":"castaway_id","full_name_x":"full_name"})
Q17 = castaway_details_merge_3[["season", "castaway_id", "full_name", "age", "age_category"]].sort_values(by = ["age","castaway_id"]).reset_index(drop = True)

# %% [markdown]
# **Q18:** Based on the age categories you created above, what are the normalized percentages for the various age categories using `value_counts()`.  Sort the value counts by index.  Save this as `Q18`.

# %%
normalization = (castaway_details_merge_3["age_category"].value_counts())/(len(castaway_details_merge_3))
index = ["18-24", "25-34", "35-44", "45-54", "55-64", "65+"]
Q18 = pd.Series(normalization, index = index)

# %% [markdown]
# **Q19:** Which contestant(s) played a perfect game?  A perfect game is considered when the contestant:
# - didn't receive any tribal council votes all season (this is different than Q10 since some players played multiple times.  They got voted out in one season so they would not show in Q10 but they came back for another season and didn't receive any tribal council votes)
# - won the game
# - got unanimous jury votes (see question 12)
#
# Save this DataFrame as `Q19` with the following columns: `season_name`, `season`, `castaway_id`, `full_name`, `tribal_council_votes`, `jury_votes`.  The DataFrame should be sorted by season and the index should be 0 to n-1.

# %%
#possible perfect winner must be one of these five#
perfect_winner = Q12.copy()
perfect_winner
# Out:
#    season                      season_name  winner_id         full_name
# 0      14                   Survivor: Fiji        221         Earl Cole
# 1      18              Survivor: Tocantins        281  James Thomas Jr.
# 2      26               Survivor: Caramoan        348      John Cochran
# 3      31               Survivor: Cambodia        433    Jeremy Collins
# 4      33  Survivor: Millennials vs. Gen X        498        Adam Klein

# %%
perfect_winner_list = perfect_winner["winner_id"].tolist()
perfect_winner_list
# Out:
# [221, 281, 348, 433, 498]

# %%
#see which of the five above had a vote ID in any season#
vote_history_perfect = vote_history[vote_history.vote_id.isin(perfect_winner_list)]
vote_history_perfect = vote_history_perfect.loc[:,["vote_id", "season"]].drop_duplicates(subset = ["vote_id","season"])
vote_history_perfect
# Out:
#       vote_id  season
# 120       498      40
# 214       433      40
# 963       281      34
# 1124      498      33
# 1437      433      31
# 1634      433      29
# 2293      348      23
# 2781      281      20
# 3365      221      14

# %%
#see all seasons the above were in#
castaway_details_perfect = castaway_details_merge[castaway_details_merge.castaway_id_x.isin(perfect_winner_list)]
castaway_details_perfect = castaway_details_perfect.loc[:,["castaway_id_x", "season"]].sort_values(by = ["castaway_id_x","season"], ascending = False)
castaway_details_perfect

#matching combos can't be perfect#
#excluded: 640, 641, 556, 557, 558, 446, 
#possible: 445(348,26), 362(281,34), 364(281,18)
# Out:
#      castaway_id_x  season
# 640            498      40
# 641            498      33
# 556            433      40
# 557            433      31
# 558            433      29
# 445            348      26
# 446            348      23
# 362            281      34
# 363            281      20
# 364            281      18
# 285            221      14

# %%
#to be perfect in the above combos they also needed to win the season#
perfect_winner = Q12.copy()
perfect_winner 
#possible perfect seasons: 445(348,26), 362(281,34), 364(281,18)
#season 34 winner was not #281#
#perfect seasons: 445(348,26),364(281,18)
# Out:
#    season                      season_name  winner_id         full_name
# 0      14                   Survivor: Fiji        221         Earl Cole
# 1      18              Survivor: Tocantins        281  James Thomas Jr.
# 2      26               Survivor: Caramoan        348      John Cochran
# 3      31               Survivor: Cambodia        433    Jeremy Collins
# 4      33  Survivor: Millennials vs. Gen X        498        Adam Klein

# %%
jury_votes_final = jury_votes[(jury_votes["finalist_id"] == 348) | (jury_votes["finalist_id"] == 281)]
jury_votes_final_2 = jury_votes_final[(jury_votes_final["season"] == 26) | (jury_votes_final["season"] == 18)]
jury_votes_final_2_grouped = jury_votes_final_2.groupby(["finalist_id"])
jury_votes_final_2_df = jury_votes_final_2_grouped.sum().reset_index()
jury_votes_final_2_df
# Out:
#    finalist_id  season  vote  castaway_id
# 0          281     126     7         1932
# 1          348     208     8         2794

# %%
final_merge = castaways.merge(vote_history, left_on = "castaway_id", right_on = "castaway_id")
final_merge_2 = final_merge[(final_merge["castaway_id"] == 348) | (final_merge["castaway_id"] == 281)]
final_merge_3 = final_merge_2[(final_merge_2["season_x"] == 26) | (final_merge["season_x"] == 18)]
final_merge_3 = final_merge_3.loc[:,["season_name_x", "season_x","castaway_id","full_name","total_votes_received"]]
final_merge_3_df = final_merge_3.drop_duplicates().reset_index(drop = True)
final_merge_4 = final_merge_3_df.merge(jury_votes_final_2_df, left_on = "castaway_id", right_on = "finalist_id")
final_merge_4 = final_merge_4.loc[:,["season_name_x","season_x","castaway_id_x","full_name","total_votes_received","vote"]]
final_merge_4 = final_merge_4.rename(columns = {"season_name_x":"season_name","season_x":"season","castaway_id_x":"castaway_id","total_votes_received":"tribal_council_votes","vote":"jury_votes"})
Q19 = final_merge_4
# Out:
# /var/folders/86/hhnttg511rx7rjhk86mrn9700000gn/T/ipykernel_33662/1148391454.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   final_merge_3 = final_merge_2[(final_merge_2["season_x"] == 26) | (final_merge["season_x"] == 18)]
